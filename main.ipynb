# %%
from binance.client import Client
from binance.enums import *
import pandas as pd
import time
import keys #you need to import a file that contains your binance api and secret key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
#       3 import pandas as pd
#       4 import time
# ----> 5 import keys
#
# ModuleNotFoundError: No module named 'keys'

# %%
apiKey = keys.apiKey
secretKey = keys.secretKey
client = Client(apiKey,secretKey)

# %%
tickers = client.get_all_tickers()
tickers
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.07102100'},
#  {'symbol': 'LTCBTC', 'price': '0.00284500'},
#  {'symbol': 'BNBBTC', 'price': '0.00953100'},
#  {'symbol': 'NEOBTC', 'price': '0.00055700'},
#  {'symbol': 'QTUMETH', 'price': '0.00251200'},
#  {'symbol': 'EOSETH', 'price': '0.00081300'},
#  {'symbol': 'SNTETH', 'price': '0.00001992'},
#  {'symbol': 'BNTETH', 'price': '0.00083200'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00011390'},
#  {'symbol': 'BNBETH', 'price': '0.13420000'},
#  {'symbol': 'BTCUSDT', 'price': '43049.77000000'},
#  {'symbol': 'ETHUSDT', 'price': '3057.39000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00001229'},
# ...

# %%
ticker_df = pd.DataFrame(tickers)

# %%
ticker_df.head()
# Out:
#     symbol       price
# 0   ETHBTC  0.07102100
# 1   LTCBTC  0.00284500
# 2   BNBBTC  0.00953100
# 3   NEOBTC  0.00055700
# 4  QTUMETH  0.00251200

# %%
ticker_df.set_index('symbol',inplace=True)

# %%
ticker_df.loc['BTCUSDT']
# Out:
# price    43049.77000000
# Name: BTCUSDT, dtype: object

# %%
float(ticker_df.loc['BTCUSDT']['price'])
# Out:
# 43049.77

# %%
client.get_account()
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'updateTime': 1639784210714,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.40659300', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.01028970', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '1.63836000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
#magic starts

# %%
posframe = pd.read_csv('strategy.csv')

# %%
posframe
# Out:
#   currency  position  quantity
# 0  BTCUSDT         0     0.002
# 1  ETHUSDT         0     0.020
# 2  ADAUSDT         0   100.000

# %%
def changePosition(curr,buy=True):
    if buy:
        posframe.loc[posframe.currency == curr, 'position'] = 1
    else:
        posframe.loc[posframe.currency == curr, 'position'] = 0
        
    posframe.to_csv('position',index=False)

# %%
def getDataHourly(symbol): #-> currency symbol
    frame = pd.DataFrame(client.get_historical_klines(symbol,'1h',
                                                     '25 hours ago UTC'))
    frame = frame.iloc[:,:5]
    frame.columns = ['Time','Open','High','Low','Close']
    frame[['Open','High','Low','Close']] = frame[['Open','High','Low','Close']].astype(float)
    frame.Time = pd.to_datetime(frame.Time,unit='ms')
    return frame

# %%
df = getDataHourly('BTCUSDT')

# %%
getDataHourly('BTCUSDT')
# Out:
#                   Time      Open      High       Low     Close
# 0  2022-03-23 12:00:00  42039.77  42438.71  41881.00  42359.04
# 1  2022-03-23 13:00:00  42359.04  42450.00  41976.87  42020.98
# 2  2022-03-23 14:00:00  42020.99  42400.01  41969.00  42392.81
# 3  2022-03-23 15:00:00  42392.81  42737.39  42302.81  42618.18
# 4  2022-03-23 16:00:00  42618.18  42775.10  42483.36  42580.51
# 5  2022-03-23 17:00:00  42580.50  42602.22  42059.00  42160.33
# 6  2022-03-23 18:00:00  42160.33  42224.16  42050.37  42087.94
# 7  2022-03-23 19:00:00  42087.94  42353.50  42070.91  42216.79
# 8  2022-03-23 20:00:00  42216.79  42407.67  42189.73  42349.72
# 9  2022-03-23 21:00:00  42349.72  42410.00  42250.80  42385.37
# 10 2022-03-23 22:00:00  42385.37  42555.99  42335.12  42488.67
# 11 2022-03-23 23:00:00  42488.66  43025.96  42398.98  42882.76
# 12 2022-03-24 00:00:00  42882.76  43276.12  42757.17  43034.72
# 13 2022-03-24 01:00:00  43034.73  43103.76  42700.00  42827.45
# ...

# %%
def applyTechnicals(df):
    df['FastSMA'] = df.Close.rolling(7).mean()
    df['SlowSMA'] = df.Close.rolling(24).mean()

# %%
applyTechnicals(df)

# %%
df
# Out:
#                   Time      Open      High       Low     Close       FastSMA  \
# 0  2022-03-23 12:00:00  42039.77  42438.71  41881.00  42359.04           NaN
# 1  2022-03-23 13:00:00  42359.04  42450.00  41976.87  42020.98           NaN
# 2  2022-03-23 14:00:00  42020.99  42400.01  41969.00  42392.81           NaN
# 3  2022-03-23 15:00:00  42392.81  42737.39  42302.81  42618.18           NaN
# 4  2022-03-23 16:00:00  42618.18  42775.10  42483.36  42580.51           NaN
# 5  2022-03-23 17:00:00  42580.50  42602.22  42059.00  42160.33           NaN
# 6  2022-03-23 18:00:00  42160.33  42224.16  42050.37  42087.94  42317.112857
# 7  2022-03-23 19:00:00  42087.94  42353.50  42070.91  42216.79  42296.791429
# 8  2022-03-23 20:00:00  42216.79  42407.67  42189.73  42349.72  42343.754286
# 9  2022-03-23 21:00:00  42349.72  42410.00  42250.80  42385.37  42342.691429
# 10 2022-03-23 22:00:00  42385.37  42555.99  42335.12  42488.67  42324.190000
# ...

# %%
#TRADING STUFF

# %%
def trader(curr):
    amount = posframe[posframe.currency == curr].quantity.values[0]
    df = getDataHourly(curr)
    applyTechnicals(df)
    lastrow = df.iloc[-1]
    if not posframe[posframe.currency == curr].position.values[0]:
        if lastrow.FastSMA > lastrow.SlowSMA:
            order = client.create_order(symbol=curr,side='BUY',type='MARKET',quantity=amount)
            print(order)
            changepos(curr,buy=True)
        else:
            print(f'Not in position {curr} but Condition not fulfilled')
    
    else:
        print(f'Already in {curr} position')
        if lastrow.SlowSMA > lastrow.FastSMA:
            order = client.create_order(symbol=curr,side='SELL',type='MARKET',quantity=amount)
            print(order)
            changepos(curr,buy=False)

# %%
posframe
# Out:
#   currency  position  quantity
# 0  BTCUSDT         0     0.002
# 1  ETHUSDT         0     0.020
# 2  ADAUSDT         0   100.000

# %%
posframe[posframe.currency == 'ADAUSDT'].quantity.values[0]
# Out:
# 100.0

# %%
try: 
    while True:
        for coin in posframe.currency:
            trader(coin)
        time.sleep(60)
except KeyboardInterrupt:
    pass
